# %% [markdown]
# ## Import Pandas library

# %%
import pandas as pd

# %% [markdown]
# ## Import csv files

# %%
df = pd.read_csv("F://Files/Python work/case study/survey_results_public.csv", index_col='ResponseId')
schema_df = pd.read_csv("F://Files/Python work/case study/survey_results_schema.csv", index_col='qid')

# %% [markdown]
# ## Change display settings for columns and rows

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %% [markdown]
# ## Check dataframe's first five rows

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %% [markdown]
# ## Filter out India from Country

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
#
#            Country US_State UK_Country  \
# ResponseId
# 9            India      NaN        NaN
# 23           India      NaN        NaN
# 40           India      NaN        NaN
# 50           India      NaN        NaN
# 53           India      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# ...

# %% [markdown]
# ## To save file in csv format

# %%
india_df.to_csv('F://Files/Python work/case study/survey_modified.csv')

# %% [markdown]
# ## To save file in tsv (tab separated) format

# %%
india_df.to_csv('F://Files/Python work/case study/survey_modified.tsv', sep='\t')

# %% [markdown]
# ## To save in Microsoft Excel format

# %%
india_df.to_excel('F://Files/Python work/case study/survey_modified.xlsx')

# %% [markdown]
# # Testing out the new saved file in Excel format

# %%
test = pd.read_excel('F://Files/Python work/case study/survey_modified.xlsx', index_col='ResponseId')

# %%
test.head()
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
#
#            Country  US_State  UK_Country  \
# ResponseId
# 9            India       NaN         NaN
# 23           India       NaN         NaN
# 40           India       NaN         NaN
# 50           India       NaN         NaN
# 53           India       NaN         NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# ...

# %% [markdown]
# ## To save file to json format

# %%
india_df.to_json('F://Files/Python work/case study/survey_modified.json', orient='records', lines=True)

# %%
test = pd.read_json('F://Files/Python work/case study/survey_modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                                MainBranch          Employment Country  \
# 0          I am a developer by profession  Employed part-time   India
# 1  I am a student who is learning to code  Student, full-time   India
# 2  I am a student who is learning to code  Student, part-time   India
# 3  I am a student who is learning to code  Student, full-time   India
# 4          I am a developer by profession  Employed full-time   India
#
#    US_State  UK_Country                                            EdLevel  \
# 0       NaN         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1       NaN         NaN  Some college/university study without earning ...
# 2       NaN         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3       NaN         NaN  Some college/university study without earning ...
# 4       NaN         NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...
