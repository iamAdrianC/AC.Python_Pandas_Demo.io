# %% [markdown]
# ## Import pandas library

# %%
import pandas as pd

# %% [markdown]
# ## Import csv files

# %%
df = pd.read_csv("F://Files/Python work/case study/survey_results_public.csv", index_col='ResponseId')
schema_df = pd.read_csv("F://Files/Python work/case study/survey_results_schema.csv", index_col='qname')

# %% [markdown]
# ## Change display settings for columns and rows

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %% [markdown]
# ## Check dataframe's first five rows

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %% [markdown]
# ## Check schema

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %% [markdown]
# ## Use filt as a variable name in order to filter out programming language is Python

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
filt
# Out:
# ResponseId
# 1        False
# 2         True
# 3         True
# 4        False
# 5         True
#          ...
# 83435    False
# 83436    False
# 83437     True
# 83438     True
# 83439    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 5                              I am a developer by profession
# 6                      I am a student who is learning to code
# 10                             I am a developer by profession
# ...                                                       ...
# 83430                             I code primarily as a hobby
# 83431                          I am a developer by profession
# 83432                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 2                                          Student, full-time
# 3                                          Student, full-time
# ...

# %% [markdown]
# ## Filter out salaries over 65000

# %%
high_salary = (df['CompTotal'] > 65000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch  \
# ResponseId
# 13                             I am a developer by profession
# 25                             I am a developer by profession
# 27          I am not primarily a developer, but I write co...
# 30                             I am a developer by profession
# 37                             I am a developer by profession
# ...                                                       ...
# 83433                          I am a developer by profession
# 83434                          I am a developer by profession
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83438                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 13                                         Employed full-time
# 25                                         Employed full-time
# ...

# %% [markdown]
# ## Filter more values

# %%
df.loc[high_salary,['Country', 'LanguageHaveWorkedWith', 'CompTotal']]
# Out:
#                              Country  \
# ResponseId
# 13                           Germany
# 25                           Germany
# 27                       Switzerland
# 30                Russian Federation
# 37          United States of America
# ...                              ...
# 83433                         Canada
# 83434                         Brazil
# 83435       United States of America
# 83436                          Benin
# 83438                         Canada
#
#                                        LanguageHaveWorkedWith  CompTotal
# ResponseId
# 13                                       C;C++;Java;Perl;Ruby    71500.0
# 25          C++;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Ty...    72000.0
# 27                                                 C++;Python    80000.0
# 30                                            Delphi;Java;SQL   200000.0
# 37                                Assembly;C;Java;Kotlin;Rust   103000.0
# ...

# %% [markdown]
# ## Filter only the following five countries

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# ResponseId
# 9          India
# 13       Germany
# 18        Canada
# 21       Germany
# 23         India
#           ...
# 83416    Germany
# 83418      India
# 83425    Germany
# 83433     Canada
# 83438     Canada
# Name: Country, Length: 19148, dtype: object

# %% [markdown]
# ## Filter Language, Python

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %% [markdown]
# ## Filter String from 'LanguageHaveWorkedWith' that have Python

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                                        JavaScript;Python
# 3                                 Assembly;C;Python;R;Rust
# 5                           Bash/Shell;HTML/CSS;Python;SQL
# 6        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                              C++;Python
#                                ...
# 83430               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                   Groovy;Java;Python
# 83438                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object
